# %% [markdown]
# # Games Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('games_played.csv')
df_to_play = pd.read_csv('games_to_play.csv')

# %%
print('Played games: ', len(df))
print('Games to play: ', len(df_to_play))
# Out:
# Played games:  223
# Games to play:  39

# %%
df.head()
# Out:
#                 title beat_date  year_I_played  score
# 0           Taz Mania      2004           2004      3
# 1       Shadow Dancer      2004           2004      3
# 2       Double Dragon      2004           2004      3
# 3     Double Dragon 2      2004           2004      3
# 4  Sonic the Hedgehog      2005           2005      3

# %%
df
# Out:
#                           title    beat_date  year_I_played  score
# 0                     Taz Mania         2004           2004      3
# 1                 Shadow Dancer         2004           2004      3
# 2                 Double Dragon         2004           2004      3
# 3               Double Dragon 2         2004           2004      3
# 4            Sonic the Hedgehog         2005           2005      3
# ..                          ...          ...            ...    ...
# 218                Metro Exodus   19/07/2021           2021      4
# 219           God of War (2018)   08/08/2021           2021      4
# 220  Uncharted 4: A Thief's End   11/08/2021           2021      4
# 221   The Last of Us Remastered   15/08/2021           2021      4
# 222      The Last of Us Part II   11/09/2021           2021      5
#
# [223 rows x 4 columns]

# %%
games_four_score = df[df['score'] == 4]
games_four_score
# Out:
#                                     title    beat_date  year_I_played  score
# 19                            Silent Hill         2007           2007      4
# 21                               Tekken 3         2007           2007      4
# 24                        Resident Evil 4         2007           2007      4
# 29                     Hitman Blood Money         2007           2007      4
# 34                         Call of Duty 2         2009           2009      4
# 35                                 Portal         2010           2010      4
# 36                     Plants vs. Zombies         2010           2010      4
# 37                                F.E.A.R         2010           2010      4
# 39                                Mafia 2         2011           2011      4
# 40         Call of Duty 4: Modern Warfare         2011           2011      4
# 42          Call of Duty Modern Warfare 2         2011           2011      4
# ...

# %%
games_top_score = df[df['score'] == 5]
games_top_score
# Out:
#                                          title    beat_date  year_I_played  \
# 52                                       Braid         2011           2011
# 53                   Amnesia: The Dark Descent         2011           2011
# 58   The Walking Dead: A Telltale Games Series      8/12/12           2012
# 95                                   Gone Home     15/12/13           2012
# 97                                    Portal 2         2013           2013
# 98                                   Minecraft         2013           2013
# 105                The Elder Scrolls V: Skyrim     19/10/14           2014
# 107                           Metal Gear Solid     02/12/14           2014
# 125                         Grand Theft Auto V     31/10/15           2015
# 128                                    Journey     11/12/15           2015
# 138                                Half-Life 2     08/01/16           2016
# ...

# %%
df.groupby('year_I_played')['title'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_I_played'>

# %%
playstation_games = df_to_play[df_to_play['score'] == ' AWAITING (Playstation exclusive)']
print('Quantidade de jogos: ', len(playstation_games))
playstation_games
# Out:
# Quantidade de jogos:  5
#                      title beat_date  year_I_played  \
# 34  Final Fantasy 7 Remake   TO PLAY           2021
# 35         Persona 5 Royal   TO PLAY           2021
# 36  Shadow of the Colossus   TO PLAY           2021
# 37       Ratchet and Clank   TO PLAY           2021
# 38              Bloodborne   TO PLAY           2021
#
#                                 score
# 34   AWAITING (Playstation exclusive)
# 35   AWAITING (Playstation exclusive)
# 36   AWAITING (Playstation exclusive)
# 37   AWAITING (Playstation exclusive)
# 38   AWAITING (Playstation exclusive)

# %%
wiiu_games = df_to_play[df_to_play['score'] == ' AWAITING (Wii U)']
print('Quantidade de jogos: ', len(wiiu_games))
wiiu_games
# Out:
# Quantidade de jogos:  3
#                                   title beat_date  year_I_played  \
# 31  The Legend of Zelda: The Wind Waker   TO PLAY           2021
# 32                 Super Mario Galaxy 2   TO PLAY           2021
# 33                   Super Mario Galaxy   TO PLAY           2021
#
#                 score
# 31   AWAITING (Wii U)
# 32   AWAITING (Wii U)
# 33   AWAITING (Wii U)

# %%
nintendo_switch_games = df_to_play[df_to_play['score'] == ' AWAITING (Nintendo Switch)']
print('Quantidade de jogos: ', len(nintendo_switch_games))
nintendo_switch_games
# Out:
# Quantidade de jogos:  4
#                                    title beat_date  year_I_played  \
# 27                   Mario Kart 8 Deluxe   TO PLAY           2021
# 28            Super Smash Bros. Ultimate   TO PLAY           2021
# 29  Super Mario 3D World + Bowser’s Fury   TO PLAY           2021
# 30        Animal Crossing™: New Horizons   TO PLAY           2021
#
#                           score
# 27   AWAITING (Nintendo Switch)
# 28   AWAITING (Nintendo Switch)
# 29   AWAITING (Nintendo Switch)
# 30   AWAITING (Nintendo Switch)
