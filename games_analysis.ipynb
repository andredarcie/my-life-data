# %% [markdown]
# # Games Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('data/games/games_beated.csv')
df_to_play = pd.read_csv('data/games/games_to_play_order_by_priority.csv')
df_games_only_played = pd.read_csv('data/games/games_only_played.csv')

# %%
print('Beated games: ', len(df))
print('Games to play: ', len(df_to_play))
print('Games only played: ', len(df_games_only_played))
# Out:
# Beated games:  137
# Games to play:  46
# Games only played:  92

# %%
df.head()
# Out:
#                 title beat_date  year_I_played  score
# 0           Taz Mania      2004           2004      3
# 1       Shadow Dancer      2004           2004      3
# 2       Double Dragon      2004           2004      3
# 3     Double Dragon 2      2004           2004      3
# 4  Sonic the Hedgehog      2005           2005      3

# %%
df
# Out:
#                           title    beat_date  year_I_played  score
# 0                     Taz Mania         2004           2004      3
# 1                 Shadow Dancer         2004           2004      3
# 2                 Double Dragon         2004           2004      3
# 3               Double Dragon 2         2004           2004      3
# 4            Sonic the Hedgehog         2005           2005      3
# ..                          ...          ...            ...    ...
# 132  Uncharted 4: A Thief's End   11/08/2021           2021      4
# 133   The Last of Us Remastered   15/08/2021           2021      4
# 134      The Last of Us Part II   11/09/2021           2021      5
# 135  Marvel's Spider-Man (2018)   19/09/2021           2021      4
# 136    A Plague Tale: Innocence   20/09/2021           2021      3
#
# [137 rows x 4 columns]

# %%
df_games_only_played
# Out:
#                                title  play_date  score
# 0                             Tetris       2006      3
# 1                        Guitar Hero       2007      3
# 2                     Guitar Hero II       2007      3
# 3   Guitar Hero III: Legends of Rock       2007      3
# 4                  Super Mario World       2010      3
# ..                               ...        ...    ...
# 87                       Baba Is You       2021      3
# 88                        Bloodborne       2021      3
# 89                        Mini Metro       2021      3
# 90                              SOMA       2021      3
# 91      Hellblade: Senua's Sacrifice       2012      3
#
# [92 rows x 3 columns]

# %%
games_four_score = df_games_only_played[df_games_only_played['score'] == 4]
games_four_score
# Out:
#                                    title  play_date  score
# 10                     Final Fantasy VII       2012      4
# 13                Shadow of the Colossus       2012      4
# 15    Castlevania: Symphony of the Night       2012      4
# 30                   Red Dead Redemption       2015      4
# 44                      This War of Mine       2018      4
# 53                    Fallout: New Vegas       2019      4
# 55      South Park™: The Stick of Truth™       2019      4
# 56                  The Binding of Isaac       2019      4
# 64                               Besiege       2020      4
# 67                             Undertale       2020      4
# 84  The Legend of Zelda: Ocarina of Time       2021      4

# %%
games_four_score = df[df['score'] == 4]
games_four_score
# Out:
#                                    title    beat_date  year_I_played  score
# 18                           Silent Hill         2007           2007      4
# 20                              Tekken 3         2007           2007      4
# 23                       Resident Evil 4         2007           2007      4
# 25                    Hitman Blood Money         2007           2007      4
# 30                        Call of Duty 2         2009           2009      4
# 31                                Portal         2010           2010      4
# 32                    Plants vs. Zombies         2010           2010      4
# 33                               F.E.A.R         2010           2010      4
# 34                               Mafia 2         2011           2011      4
# 35        Call of Duty 4: Modern Warfare         2011           2011      4
# 37         Call of Duty Modern Warfare 2         2011           2011      4
# 50                              Farcry 3     11/12/12           2012      4
# 51          Warcraft III: Reign of Chaos     25/03/13           2012      4
# 53                              BioShock     28/03/13           2012      4
# 59                        Hotline: Miami     10/07/13           2012      4
# 71                             Half-Life     23/01/14           2014      4
# 79         The Vanishing of Ethan Carter     04/12/14           2014      4
# 80                           To The Moon     08/12/14           2014      4
# 81   Metal Gear Solid 2: Sons of Liberty     14/12/14           2014      4
# 82       Metal Gear Solid 3: Snake Eater     22/12/14           2014      4
# 91                                 LIMBO     01/08/15           2015      4
# 93                       Life is Strange     11/11/15           2015      4
# 94                        The Last of Us     11/12/15           2015      4
# 109                  The Legend of Zelda   07/07/2020           2020      4
# 110                              Celeste   23/09/2020           2020      4
# 118          What Remains of Edith Finch   26/10/2020           2020      4
# 121               Resident Evil 2 (2019)   28/01/2021           2021      4
# 128                         A Short Hike   17/07/2021           2021      4
# 129                Resident Evil Village   18/07/2021           2021      4
# 130                         Metro Exodus   19/07/2021           2021      4
# 131                    God of War (2018)   08/08/2021           2021      4
# 132           Uncharted 4: A Thief's End   11/08/2021           2021      4
# 133            The Last of Us Remastered   15/08/2021           2021      4
# 135           Marvel's Spider-Man (2018)   19/09/2021           2021      4

# %%
games_top_score = df[df['score'] == 5]
games_top_score
# Out:
#                                          title    beat_date  year_I_played  \
# 45                                       Braid         2011           2011
# 46                   Amnesia: The Dark Descent         2011           2011
# 49   The Walking Dead: A Telltale Games Series      8/12/12           2012
# 66                                   Gone Home     15/12/13           2012
# 68                                    Portal 2         2013           2013
# 69                                   Minecraft         2013           2013
# 76                 The Elder Scrolls V: Skyrim     19/10/14           2014
# 78                            Metal Gear Solid     02/12/14           2014
# 92                          Grand Theft Auto V     31/10/15           2015
# 95                                     Journey     11/12/15           2015
# 99                                 Half-Life 2     08/01/16           2016
# 103                   The Witcher 3: Wild Hunt     11/07/16           2016
# 104                                     INSIDE     12/12/16           2016
# 111                        Super Mario Odyssey   09/10/2020           2020
# 116    The Legend of Zelda: Breath of the Wild   25/10/2020           2020
# 119                              Disco Elysium   12/12/2020           2020
# 134                     The Last of Us Part II   11/09/2021           2021
#
#      score
# 45       5
# 46       5
# 49       5
# 66       5
# 68       5
# 69       5
# 76       5
# 78       5
# 92       5
# 95       5
# 99       5
# 103      5
# 104      5
# 111      5
# 116      5
# 119      5
# 134      5

# %%
len(games_top_score)
# Out:
# 17

# %%
df.groupby('year_I_played')['title'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_I_played'>

# %%
df_to_play.groupby(by=["where_to_play"]).count()
# Out:
#                title
# where_to_play
#  GAME_PASS         9
#  PC               14
#  PC VR             1
#  PS5              17
#  SWITCH            5
