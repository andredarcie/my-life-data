# %% [markdown]
# # Games Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('games.csv')

# %%
df.head()
# Out:
#                             title    beat_date  year_I_played score
# 0   Brothers - A Tale of Two Sons   NOT BEATED           2018     3
# 1  Valiant Hearts: The Great War™   NOT BEATED           2018     3
# 2             The Talos Principle   NOT BEATED           2018     3
# 3                   Borderlands 2   NOT BEATED           2018     2
# 4                This War of Mine   NOT BEATED           2018     4

# %%
df
# Out:
#                                    title    beat_date  year_I_played  \
# 0          Brothers - A Tale of Two Sons   NOT BEATED           2018
# 1         Valiant Hearts: The Great War™   NOT BEATED           2018
# 2                    The Talos Principle   NOT BEATED           2018
# 3                          Borderlands 2   NOT BEATED           2018
# 4                       This War of Mine   NOT BEATED           2018
# ..                                   ...          ...            ...
# 56                            Mini Metro      TO PLAY           2021
# 57                        Desperados III      TO PLAY           2021
# 58                          Spiritfarer®      TO PLAY           2021
# 59                      missed messages.      TO PLAY           2021
# 60  Super Mario 3D World + Bowser’s Fury      TO PLAY           2021
#
#         score
# 0           3
# 1           3
# 2           3
# 3           2
# 4           4
# ..        ...
# 56   AWAITING
# 57   AWAITING
# 58   AWAITING
# 59   AWAITING
# 60   AWAITING
#
# [61 rows x 4 columns]

# %%
games_top_score = df[df['score'] == ' 5']
games_top_score
# Out:
#                                          title    beat_date  year_I_played  \
# 52                                       Braid         2011         2011.0
# 53                   Amnesia: The Dark Descent         2011         2011.0
# 58   The Walking Dead: A Telltale Games Series      8/12/12         2012.0
# 95                                   Gone Home     15/12/13         2012.0
# 97                                    Portal 2         2013         2013.0
# 98                                   Minecraft         2013         2013.0
# 105                The Elder Scrolls V: Skyrim     19/10/14         2014.0
# 107                           Metal Gear Solid     02/12/14         2014.0
# 125                         Grand Theft Auto V     31/10/15         2015.0
# 128                                    Journey     11/12/15         2015.0
# 138                                Half-Life 2     08/01/16         2016.0
# 142                   The Witcher 3: Wild Hunt     11/07/16         2016.0
# 143                                     INSIDE     12/12/16         2016.0
# 185                        Super Mario Odyssey   09/10/2020         2020.0
# 190    The Legend of Zelda: Breath of the Wild   25/10/2020         2020.0
# 193                              Disco Elysium   12/12/2020         2020.0
#
#     score
# 52      5
# 53      5
# 58      5
# 95      5
# 97      5
# 98      5
# 105     5
# 107     5
# 125     5
# 128     5
# 138     5
# 142     5
# 143     5
# 185     5
# 190     5
# 193     5

# %%
df.groupby('year_I_played')['title'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_I_played'>
