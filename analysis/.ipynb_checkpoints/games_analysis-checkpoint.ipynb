# %% [markdown]
# # Games Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/games/games_beated.csv')
df_to_play = pd.read_csv('../data/games/games_to_play.csv')
df_games_only_played = pd.read_csv('../data/games/games_abandoned.csv')

# %%
print('Beated games: ', len(df))
print('Games only played: ', len(df_games_only_played))
print('Games to play: ', len(df_to_play))
# Out:
# Beated games:  170
# Games only played:  144
# Games to play:  10

# %%
df
# Out:
#                   title    beat_date  year_I_played      plataform  score
# 0             Taz Mania         2004           2004     Mega Drive      3
# 1         Shadow Dancer         2004           2004     Mega Drive      3
# 2         Double Dragon         2004           2004     Mega Drive      3
# 3       Double Dragon 2         2004           2004     Mega Drive      3
# 4    Sonic the Hedgehog         2005           2005     Mega Drive      3
# ..                  ...          ...            ...            ...    ...
# 165            Tekken 7   22/02/2023           2023  PlayStation 5      3
# 166            Tekken 2   25/02/2023           2023  PlayStation 5      3
# 167    Before Your Eyes   15/03/2023           2023             PC      4
# 168         DOOM (2016)   15/03/2023           2023  PlayStation 5      3
# 169     Hogwarts Legacy   19/03/2023           2023  PlayStation 5      3
#
# [170 rows x 5 columns]

# %%
df_games_only_played
# Out:
#                                 title  play_date  score  \
# 0                              Tetris       2006      3
# 1                         Guitar Hero       2007      3
# 2                      Guitar Hero II       2007      3
# 3    Guitar Hero III: Legends of Rock       2007      3
# 4                   Super Mario World       2010      3
# ..                                ...        ...    ...
# 139                      Rez Infinite       2023      3
# 140                     What The Bat?       2023      3
# 141                 The Light Brigade       2023      3
# 142               Destroy All Humans!       2023      3
# 143              Marvel's Iron Man VR       2023      3
#
#                                                 reason
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 139   Um dos jogos mais diferentes que joguei mas é...
# 140   Varios mini games bem simples com visual infa...
# 141   Abandonei pela dificuldade e ser roguelike qu...
# 142   Com o passar do tempo as missões só repetem e...
# 143   É dificil voar e ser preciso e isso é basicam...
#
# [144 rows x 4 columns]

# %%
games_four_score = df_games_only_played[df_games_only_played['score'] == 4]
games_four_score
# Out:
#                                     title  play_date  score reason
# 10                      Final Fantasy VII       2012      4    NaN
# 13                 Shadow of the Colossus       2012      4    NaN
# 15     Castlevania: Symphony of the Night       2012      4    NaN
# 30                    Red Dead Redemption       2015      4    NaN
# 44                       This War of Mine       2018      4    NaN
# 53                     Fallout: New Vegas       2019      4    NaN
# 55       South Park™: The Stick of Truth™       2019      4    NaN
# 56                   The Binding of Isaac       2019      4    NaN
# 64                                Besiege       2020      4    NaN
# 67                              Undertale       2020      4    NaN
# 84   The Legend of Zelda: Ocarina of Time       2021      4    NaN
# 99                         Sea of Thieves       2021      4    NaN
# 105                                Dreams       2022      4    NaN
# 106                              Factorio       2022      4    NaN
# 107            Sky: Children of the Light       2022      4    NaN
# 108                           Baba Is You       2022      4    NaN

# %%
games_four_score = df[df['score'] == 4]
games_four_score
# Out:
#                                        title    beat_date  year_I_played  \
# 18                               Silent Hill         2007           2007
# 130               PC      4
# 131    PlayStation 5      4
# 132    PlayStation 5      4
# 133    PlayStation 5      4
# 134    PlayStation 5      4
# 136    PlayStation 5      4
# 140    PlayStation 5      4
# 141    PlayStation 5      4
# 142               PC      4
# 146    PlayStation 5      4
# 149  Nintendo Switch      4
# 150    PlayStation 5      4
# 160    PlayStation 5      4
# 162    PlayStation 5      4
# 163     Meta Quest 2      4
# 167               PC      4

# %%
games_top_score = df[df['score'] == 5]
games_top_score
# Out:
#                                          title    beat_date  year_I_played  \
# 46                   Amnesia: The Dark Descent         2011           2011
# 49   The Walking Dead: A Telltale Games Series      8/12/12           2012
# 66                                   Gone Home     15/12/13           2012
# 68                                    Portal 2         2013           2013
# 69                                   Minecraft         2013           2013
# 76                 The Elder Scrolls V: Skyrim     19/10/14           2014
# 78                            Metal Gear Solid     02/12/14           2014
# 92                          Grand Theft Auto V     31/10/15           2015
# 95                                     Journey     11/12/15           2015
# 99                                 Half-Life 2     08/01/16           2016
# 103                   The Witcher 3: Wild Hunt     11/07/16           2016
# 104                                     INSIDE     12/12/16           2016
# 111                        Super Mario Odyssey   09/10/2020           2020
# 119                              Disco Elysium   12/12/2020           2020
# 135                     The Last of Us Part II   11/09/2021           2021
# 164                            Half-Life: Alyx   21/02/2023           2023
#
#            plataform  score
# 46                PC      5
# 49                PC      5
# 66                PC      5
# 68                PC      5
# 69                PC      5
# 76                PC      5
# 78                PC      5
# 92                PC      5
# 95     PlayStation 3      5
# 99                PC      5
# 103               PC      5
# 104               PC      5
# 111  Nintendo Switch      5
# 119               PC      5
# 135    PlayStation 5      5
# 164     Meta Quest 2      5

# %%
len(games_top_score)
# Out:
# 16

# %%
consoles = df
consoles = consoles.drop(consoles[consoles.plataform == "PC"].index)
consoles.groupby('plataform')['plataform'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='plataform'>

# %%
df.groupby('plataform')['plataform'].count().plot(kind='pie').set_facecolor('white')

# %%
df.groupby('year_I_played')['title'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_I_played'>

# %% [markdown]
# Melhores jogos que joguei no ano de 2022

# %%
df[(df['year_I_played'] == 2022) & (df['score'] == 4)]
# Out:
#                             title    beat_date  year_I_played  \
# 141             Ghost of Tsushima   09/01/2022           2022
# 142                     Unpacking   09/01/2022           2022
# 146  Star Wars Jedi: Fallen Order   24/06/2022           2022
# 149                     Firewatch   13/08/2022           2022
# 150      Final Fantasy VII Remake   04/09/2022           2022
# 160           God of War Ragnarök   25/11/2022           2022
#
#            plataform  score
# 141    PlayStation 5      4
# 142               PC      4
# 146    PlayStation 5      4
# 149  Nintendo Switch      4
# 150    PlayStation 5      4
# 160    PlayStation 5      4

# %%
df_to_play.groupby(by=["where_to_play"]).count()
# Out:
#                title  opencritic_score   ready_to_play
# where_to_play
#  PC                1                 1               0
#  PCVR              1                 1               1
#  PS5               4                 4               1
#  PSVR 2            3                 3               0
